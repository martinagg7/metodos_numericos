# %% [markdown]
# # Método euler para estimar ecuaciones

# %%
import numpy as no

# %%
def euler(f,t0,tf,x0,n):
  """
  t0,tf :intervalo para aproximar el valor x(t)
  x0: f(t0)=x0
  n:num de intervalor
  """
  h=(tf-t0)/n
  t=np.linspace(t0,tn,n+1)
  x=np.zeros(len(t))
   for i in range(1, len(ts)):
        xs[i] = xs[i-1] + h * f(ts[i-1], xs[i-1])

    return ts, xs
